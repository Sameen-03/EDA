# %% [markdown]
# ## =======================EDA=======================
#
# 1) **pandas**     : Data frame operations
# 2) **numpy**      : math operations
# 3) **matplotlib** : plotting **or** graphs
# 4) **seaborn**    : plotting **or** graphs
# 5) **plotly**     : plotting **or** graphs
# 6) **bokeh**      : plotting **or** graphs
#
# ## =======================Machine learning=======================
#
# 7) **scikit-learn** : For all ML algorithms
# 8) **stats**        : some statistical operations
# 9) **MLlib**        : used to access ml models on pyspark
#
# ## =======================Deep learning=========================
#
# 10) **Tensorflow**   : Deep learning models (Google)
# 11) **Keras**        : Deep learning models (backed by tensorflow)
# 12) **Pytorch**      : Deep learning models (meta)
# 13) **opencv**       : Image and audio operations
# 14) **pillow**       : Image operations
#
# ## ============== Object Detection models (Transfer learning) ==============
#
# 14) **Mobilenet**     : Deep learning packages
# 15) **VGGnet**        : Deep learning packages
# 16) **Resnet**        : Deep learning packages
# 17) **Inceptionv3**   : Deep learning packages
# 18) **YOLO**          : Deep learning pa
#
# ## ====================== Natural Language Process ======================
#
# 19) **NLTK**        : Natural Language Tool Kit
# 20) **SpaCy**       : Alternative to NLTK
# 21) **Wordcloud**   : Text representation
#
#
# ## =================== NLP Word Embedding Models ===================
#
# 22) **Word2Vec**     : Google
# 23) **GloVe**        : Stanford
# 24) **FastText**     : Meta (Fa## =================== ALLEN NLP =================================
#
# 25) **NLP applications** : Pyspark as backend
#
# ## ==================== Optical character recognition (OCR) =================
# extract text from image
#
# 26) Tesseract
# 27) easyocr
#
# ## ==================== BERT =========================
# Bi directional Encoded Representations from Tranformers
#
# 28) Transformers       : Hugging face (Google)
#
# ## ==================== Webscraping ===================
#
# 29) SQLite             : Connect the database using python
# 30) Selenium
# 31) Beautiful soup
# 32) Regex
#
# ## ===================== GenAI **and** LLM =====================
#
# 33) **Langchain**   : To connect **all** LLM models
# 34) **GPT**         : OpenAI
# 35) **Gemini**      : Google
# 36) **Llama**       : Meta
# 37) **Grok**        : xAI
# 38) **BedRock**     : Amazon
# 39) **Claude AI**   : Anth
# ## ====================== Agentic AI =============================
#
# 40) Langraph
# 41) crewai
# 42) phidata
# 43) autogen
#
# ## ====================== API creation ============================
#
# 44) Flask
# 45) FastAPI
# 46) Gradio
# 47) Django
#
# ## ====================== Web application ===========================
#
# 48) Streamlit
#
# ## ====================== Model deployment ===========================
#
# 49) mlflow
# 50) kuberflow
#
# ## ======================= cloud AI ===================================
#
# 51) Azure cognitive services
# 52) Azure ML studio
# 53) GCP vertexAI
# 54) AWS sagemarks
#
# ## ======================= Extra ======================================
#
# 55) random
# 56) time
# 57) math
# 58) logging
# 59) warnings
# 60) dateropic
# cebook)
# ages
